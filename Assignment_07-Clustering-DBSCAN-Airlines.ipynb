# %% [markdown]
# ## DBSCAN Cluster from Airlines Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
# Import Dataset
airline=pd.read_csv(R"\Users\ammaurya\Desktop\Data Science\Assignments\7-Clustering\EastWestAirlines.csv")
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
# Normalize heterogenous numerical data using standard scalar fit transform to dataset
airline_norm=StandardScaler().fit_transform(airline)
airline_norm
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
# DBSCAN Clustering
dbscan=DBSCAN(eps=1,min_samples=4)
dbscan.fit(airline_norm)
# Out:
# DBSCAN(eps=1, min_samples=4)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
# Adding clusters to dataset
airline['clusters']=dbscan.labels_
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.groupby('clusters').agg(['mean']).reset_index()
# Out:
#    clusters          ID#        Balance   Qual_miles cc1_miles cc2_miles  \
#                     mean           mean         mean      mean      mean
# 0        -1  1737.833052  177646.939292   899.406408  2.701518  1.062395
# 1         0  2178.729212   53148.905529     2.084023  1.660427  1.000000
# 2         1  1799.892351   61006.745987     5.796034  2.605288  1.000000
# 3         2  1382.750000   35251.500000  1058.750000  1.000000  1.000000
# 4         3  1324.285714   65419.714286     0.000000  1.000000  1.000000
# 5         4  1363.000000   60932.000000  1794.500000  3.750000  1.000000
# 6         5  2557.230769   34806.538462     0.000000  1.000000  2.000000
# 7         6  1830.500000   32730.750000     0.000000  1.000000  3.000000
# 8         7  2672.000000   81738.000000     0.000000  1.000000  1.000000
# 9         8  3215.375000   28382.500000  2578.500000  1.000000  1.000000
# 10        9  3145.166667   52967.000000     0.000000  1.000000  1.000000
#
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(airline['clusters'],airline['Bonus_miles'],airline['Bonus_trans'], c=dbscan.labels_)
